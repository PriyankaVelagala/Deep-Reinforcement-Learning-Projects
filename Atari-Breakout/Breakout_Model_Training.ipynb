# %% [markdown]
# #Setup

# %%
import urllib.request
urllib.request.urlretrieve('http://www.atarimania.com/roms/Roms.rar','Roms.rar')
# !pip install unrar
# !unrar x Roms.rar

# !pip3 install atari-py

# !python -m atari_py.import_roms ROMS

# !pip install "gym[atari]" "gym[accept-rom-license]" atari_py

# !pip install -U "ray[rllib]==1.11.0"

# Visualizer setup
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %%
# !pip install -U "ray[rllib]==1.11.0"

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import gym
import torch

import numpy as np
from collections import namedtuple
import random, math
import matplotlib.pyplot as plt
from ray.rllib.models import ModelCatalog

from ray.rllib.env.env_context import EnvContext
import time
import os

from gym.spaces import Discrete, Box
from ray import tune
import ray
import ray.rllib.agents.dqn as dqn

# %%
# Visualizer setup
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# %% [markdown]
# # Code for visualization

# %%
# How to get gym AI visuals in colab
# https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_12_01_ai_gym.ipynb#scrollTo=T9RpF49oOsZj

from gym.wrappers import Monitor
import glob
import io
import base64
from IPython.display import HTML
from pyvirtualdisplay import Display
from IPython import display as ipythondisplay

display = Display(visible=0, size=(1400, 900))
display.start()

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay 
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else: 
    print("Could not find video")
    

def wrap_env(env):
  env = Monitor(env, './video', force=True)
  return env

# %% [markdown]
# # Test env with random actions

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("device: ", device)

game =  'Breakout-ram-v0' 
env =  wrap_env(gym.make(game))

print("game: ", game)
num_states = env.observation_space.shape[0]
num_actions = env.action_space.n

print("States size:", num_states, "Actions size: ",  num_actions)
# Out:
# device:  cuda:0
# game:  Breakout-ram-v0
# States size: 128 Actions size:  4

# %%
done = False

env.reset()

total_reward = 0 
while not done:
    env.render()
    state, reward, done, _ = env.step(env.action_space.sample()) # take a random action
    total_reward += reward

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# # Set config based on best hyper param

# %%
ray.shutdown()
ray.init(num_cpus= 2, num_gpus=1)
# Out:
# {'address': '172.28.0.2:61908',
#  'gcs_address': '172.28.0.2:61908',
#  'metrics_export_port': 48233,
#  'node_id': '41376145bfc1a60cb54fa1f3aed1d94eec824c2cef3ef1a5c1e3c760',
#  'node_ip_address': '172.28.0.2',
#  'object_store_address': '/tmp/ray/session_2022-04-22_20-14-10_018819_72/sockets/plasma_store',
#  'raylet_ip_address': '172.28.0.2',
#  'raylet_socket_name': '/tmp/ray/session_2022-04-22_20-14-10_018819_72/sockets/raylet',
#  'redis_address': None,
#  'session_dir': '/tmp/ray/session_2022-04-22_20-14-10_018819_72',
#  'webui_url': None}

# %%
config = dqn.DEFAULT_CONFIG.copy()

config["dueling"] = True
config["double_q"] = False
config["noisy"] = True
config["prioritized_replay"] = True


#evluation config 
config["evaluation_interval"] =  10
config["evaluation_config"] = {"explore": False} 

config["env"] = 'Breakout-ram-v0' 

config["model"] = {"fcnet_hiddens": [128],
                  "fcnet_activation": 'relu',
                   }

config["num_gpus"] = 1
model_train_config = config

# %%
analysis = tune.run("DQN",
                    stop={"episode_reward_mean": 5},
                    config = model_train_config,
                    local_dir = "/content/drive/MyDrive/INM707/breakout_v1",
                    checkpoint_freq = 10
                    )

#print("Best hyperparameters found were: ", analysis.best_config)
# Out:
# (DQNTrainer pid=1651) 2022-04-22 20:58:53,972	INFO trainer.py:2141 -- Your framework setting is 'tf', meaning you are using static-graph mode. Set framework='tf2' to enable eager execution with tf2.x. You may also then want to set eager_tracing=True in order to reach similar execution speed as with static-graph mode.
# (DQNTrainer pid=1651) 2022-04-22 20:58:53,973	INFO simple_q.py:155 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting `simple_optimizer=True` if this doesn't work for you.
# (DQNTrainer pid=1651) 2022-04-22 20:58:53,973	INFO trainer.py:781 -- Current log_level is WARN. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (DQNTrainer pid=1651) 2022-04-22 20:58:59,060	WARNING deprecation.py:46 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# == Status ==<br>Current time: 2022-04-22 20:59:02 (running for 00:00:12.69)<br>Memory usage on this node: 2.7/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td></tr>
# </tbody>
# </table><br><br>
# (DQNTrainer pid=1651) 2022-04-22 20:59:02,762	WARNING util.py:55 -- Install gputil for GPU system monitoring.
# == Status ==<br>Current time: 2022-04-22 20:59:03 (running for 00:00:13.74)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 1000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-07
#   done: false
#   episode_len_mean: 259.0
#   episode_media: {}
#   episode_reward_max: 3.0
#   episode_reward_mean: 1.3333333333333333
#   episode_reward_min: 0.0
#   episodes_this_iter: 3
#   episodes_total: 3
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 1000
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 0.6463987827301025
#           mean_q: 0.07603371888399124
#           mean_td_error: -0.4412388503551483
#           min_q: -0.8483760356903076
#           model: {}
#         td_error:
#         - -0.419186532497406
#         - -0.1831558346748352
#         - -0.10791763663291931
#         - -0.1420905888080597
#         - -0.4121747314929962
#         - -0.9172872304916382
#         - -0.07762652635574341
#         - -1.1191010475158691
#         - -0.9250389337539673
#         - 0.1233549416065216
#         - -0.12724071741104126
#         - -1.0546717643737793
#         - -0.07032167911529541
#         - -1.0980284214019775
#         - -0.09788304567337036
#         - -0.30594608187675476
#         - 0.22924897074699402
#         - -0.8663140535354614
#         - -0.2947154641151428
#         - 0.03406631946563721
#         - -0.14442315697669983
#         - -1.407249927520752
#         - -0.3569580614566803
#         - -0.3783537745475769
#         - 0.04543638229370117
#         - -1.1996049880981445
#         - -1.0276950597763062
#         - -1.42841374874115
#         - 0.13241907954216003
#         - -0.20722445845603943
#         - 0.14161109924316406
#         - -0.45715659856796265
#         train: null
#     num_agent_steps_sampled: 1000
#     num_agent_steps_trained: 32
#     num_steps_sampled: 1000
#     num_steps_trained: 32
#     num_steps_trained_this_iter: 32
#     num_target_updates: 1
#   iterations_since_restore: 1
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 58.357142857142854
#     ram_util_percent: 22.185714285714287
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07796501898979927
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5919085396872414
#     mean_inference_ms: 2.880989373861612
#     mean_raw_obs_processing_ms: 0.19709070722063582
#   time_since_restore: 4.4047770500183105
#   time_this_iter_s: 4.4047770500183105
#   time_total_s: 4.4047770500183105
#   timers:
#     learn_throughput: 114.301
#     learn_time_ms: 279.963
#     load_throughput: 1066.557
#     load_time_ms: 30.003
#   timestamp: 1650661147
#   timesteps_since_restore: 32
#   timesteps_this_iter: 32
#   timesteps_total: 1000
#   training_iteration: 1
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:09 (running for 00:00:19.13)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     1</td><td style="text-align: right;">         4.40478</td><td style="text-align: right;">1000</td><td style="text-align: right;"> 1.33333</td><td style="text-align: right;">                   3</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               259</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 2000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-13
#   done: false
#   episode_len_mean: 282.0
#   episode_media: {}
#   episode_reward_max: 3.0
#   episode_reward_mean: 1.7142857142857142
#   episode_reward_min: 0.0
#   episodes_this_iter: 4
#   episodes_total: 7
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 1504
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 1.236103892326355
#           mean_q: 0.8909989595413208
#           mean_td_error: 0.20070534944534302
#           min_q: 0.6692092418670654
#           model: {}
#         td_error:
#         - 0.08183419704437256
#         - 0.2870601415634155
#         - -0.029311299324035645
#         - 0.3144382834434509
#         - 0.15218102931976318
#         - -0.018638432025909424
#         - -0.01642841100692749
#         - 0.35739266872406006
#         - 0.28007078170776367
#         - -0.0839185118675232
#         - 0.37330466508865356
#         - 0.11162567138671875
#         - 0.1384865641593933
#         - 0.3325340151786804
#         - 0.11847609281539917
#         - 0.4747883677482605
#         - 0.3671872019767761
#         - 0.08303618431091309
#         - 0.2826036214828491
#         - 0.06792086362838745
#         - 0.243719220161438
#         - 0.3028455972671509
#         - 0.14721548557281494
#         - 0.44239377975463867
#         - 0.35927730798721313
#         - 0.05385899543762207
#         - 0.2956883907318115
#         - 0.14848989248275757
#         - 0.2753012776374817
#         - -0.0010775923728942871
#         - 0.06227290630340576
#         - 0.41794222593307495
#         train: null
#     num_agent_steps_sampled: 2000
#     num_agent_steps_trained: 8032
#     num_steps_sampled: 2000
#     num_steps_trained: 8032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 2
#   iterations_since_restore: 2
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 64.25555555555556
#     ram_util_percent: 22.4
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07920131704161615
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5919571285565944
#     mean_inference_ms: 2.7949311942138406
#     mean_raw_obs_processing_ms: 0.2014865594897632
#   time_since_restore: 10.618303298950195
#   time_this_iter_s: 6.213526248931885
#   time_total_s: 10.618303298950195
#   timers:
#     learn_throughput: 5880.759
#     learn_time_ms: 5.441
#     load_throughput: 32615.909
#     load_time_ms: 0.981
#   timestamp: 1650661153
#   timesteps_since_restore: 64
#   timesteps_this_iter: 32
#   timesteps_total: 2000
#   training_iteration: 2
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:14 (running for 00:00:24.44)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     2</td><td style="text-align: right;">         10.6183</td><td style="text-align: right;">2000</td><td style="text-align: right;"> 1.71429</td><td style="text-align: right;">                   3</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               282</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 20:59:19 (running for 00:00:29.44)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     2</td><td style="text-align: right;">         10.6183</td><td style="text-align: right;">2000</td><td style="text-align: right;"> 1.71429</td><td style="text-align: right;">                   3</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               282</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 3000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-19
#   done: false
#   episode_len_mean: 277.4
#   episode_media: {}
#   episode_reward_max: 3.0
#   episode_reward_mean: 1.8
#   episode_reward_min: 0.0
#   episodes_this_iter: 3
#   episodes_total: 10
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 2512
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 0.937225341796875
#           mean_q: 0.722423791885376
#           mean_td_error: -0.14536988735198975
#           min_q: 0.40495938062667847
#           model: {}
#         td_error:
#         - -0.30032360553741455
#         - -0.3058655858039856
#         - 0.14009428024291992
#         - -0.2103884220123291
#         - -0.03303462266921997
#         - 0.07803851366043091
#         - -0.10929721593856812
#         - -0.1404147744178772
#         - -0.12141254544258118
#         - -0.046019554138183594
#         - -0.09277617931365967
#         - -0.23319613933563232
#         - -0.3748473525047302
#         - -0.24637866020202637
#         - -0.12035685777664185
#         - -0.21556222438812256
#         - -0.033097028732299805
#         - -0.23214232921600342
#         - 0.006455898284912109
#         - -0.22632431983947754
#         - -0.2822993993759155
#         - -0.29598987102508545
#         - -0.23307722806930542
#         - -0.020428180694580078
#         - -0.041680097579956055
#         - 0.08219796419143677
#         - -0.10885649919509888
#         - -0.07354992628097534
#         - -0.23725676536560059
#         - -0.2879142761230469
#         - -0.3018542528152466
#         - -0.03427910804748535
#         train: null
#     num_agent_steps_sampled: 3000
#     num_agent_steps_trained: 16032
#     num_steps_sampled: 3000
#     num_steps_trained: 16032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 4
#   iterations_since_restore: 3
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 65.15555555555557
#     ram_util_percent: 22.4
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07938258832343462
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.59207352613034
#     mean_inference_ms: 2.759579946243592
#     mean_raw_obs_processing_ms: 0.20234129740987758
#   time_since_restore: 16.8115291595459
#   time_this_iter_s: 6.193225860595703
#   time_total_s: 16.8115291595459
#   timers:
#     learn_throughput: 5444.762
#     learn_time_ms: 5.877
#     load_throughput: 32053.526
#     load_time_ms: 0.998
#   timestamp: 1650661159
#   timesteps_since_restore: 96
#   timesteps_this_iter: 32
#   timesteps_total: 3000
#   training_iteration: 3
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:24 (running for 00:00:34.67)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     3</td><td style="text-align: right;">         16.8115</td><td style="text-align: right;">3000</td><td style="text-align: right;">     1.8</td><td style="text-align: right;">                   3</td><td style="text-align: right;">                   0</td><td style="text-align: right;">             277.4</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 4000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-26
#   done: false
#   episode_len_mean: 257.46666666666664
#   episode_media: {}
#   episode_reward_max: 3.0
#   episode_reward_mean: 1.4666666666666666
#   episode_reward_min: 0.0
#   episodes_this_iter: 5
#   episodes_total: 15
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 3520
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 1.3454489707946777
#           mean_q: 0.9282121658325195
#           mean_td_error: -0.05688118934631348
#           min_q: 0.656818151473999
#           model: {}
#         td_error:
#         - -0.06847202777862549
#         - -0.20331543684005737
#         - 0.07496678829193115
#         - 0.0716238021850586
#         - -0.13081514835357666
#         - -0.01062387228012085
#         - -0.25863581895828247
#         - -0.08725529909133911
#         - 0.019507884979248047
#         - -0.30440962314605713
#         - -0.12742960453033447
#         - 0.010310530662536621
#         - 0.0009533166885375977
#         - 0.024825215339660645
#         - -0.13081514835357666
#         - -0.0017462968826293945
#         - 0.09861254692077637
#         - -0.07876604795455933
#         - 0.02448594570159912
#         - -0.07945764064788818
#         - -0.06377482414245605
#         - 0.025433242321014404
#         - -0.21856319904327393
#         - -0.04169422388076782
#         - -0.00415802001953125
#         - 0.11578869819641113
#         - 0.00016117095947265625
#         - -0.11927288770675659
#         - -0.18280529975891113
#         - 0.08346134424209595
#         - -0.11601585149765015
#         - -0.14230221509933472
#         train: null
#     num_agent_steps_sampled: 4000
#     num_agent_steps_trained: 24032
#     num_steps_sampled: 4000
#     num_steps_trained: 24032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 6
#   iterations_since_restore: 4
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 69.63333333333334
#     ram_util_percent: 22.1
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07957725242244637
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5940179043857514
#     mean_inference_ms: 2.7350554213429707
#     mean_raw_obs_processing_ms: 0.20822603656179772
#   time_since_restore: 23.48636245727539
#   time_this_iter_s: 6.674833297729492
#   time_total_s: 23.48636245727539
#   timers:
#     learn_throughput: 5707.822
#     learn_time_ms: 5.606
#     load_throughput: 32294.153
#     load_time_ms: 0.991
#   timestamp: 1650661166
#   timesteps_since_restore: 128
#   timesteps_this_iter: 32
#   timesteps_total: 4000
#   training_iteration: 4
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:30 (running for 00:00:40.30)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     4</td><td style="text-align: right;">         23.4864</td><td style="text-align: right;">4000</td><td style="text-align: right;"> 1.46667</td><td style="text-align: right;">                   3</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           257.467</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 5000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-32
#   done: false
#   episode_len_mean: 250.6315789473684
#   episode_media: {}
#   episode_reward_max: 3.0
#   episode_reward_mean: 1.3157894736842106
#   episode_reward_min: 0.0
#   episodes_this_iter: 4
#   episodes_total: 19
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 4528
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 1.4165387153625488
#           mean_q: 0.9953875541687012
#           mean_td_error: -0.21886014938354492
#           min_q: 0.6771299242973328
#           model: {}
#         td_error:
#         - -0.13180530071258545
#         - -0.04220843315124512
#         - -0.3302854299545288
#         - -0.1571645736694336
#         - -0.27567553520202637
#         - -0.3060178756713867
#         - -0.2654072046279907
#         - -0.11413699388504028
#         - -0.22922343015670776
#         - -0.1396956443786621
#         - -0.7396664023399353
#         - -0.11120891571044922
#         - -0.43264222145080566
#         - -0.21832549571990967
#         - -0.18995749950408936
#         - -0.1691606044769287
#         - -0.1388283371925354
#         - -0.04727649688720703
#         - -0.24801552295684814
#         - -0.20816946029663086
#         - -0.10911905765533447
#         - -0.21001207828521729
#         - -0.15390396118164062
#         - -0.21084660291671753
#         - -0.310316801071167
#         - -0.17319369316101074
#         - -0.05175209045410156
#         - -0.1883014440536499
#         - -0.1629413366317749
#         - -0.1387341022491455
#         - -0.47471821308135986
#         - -0.3248137831687927
#         train: null
#     num_agent_steps_sampled: 5000
#     num_agent_steps_trained: 32032
#     num_steps_sampled: 5000
#     num_steps_trained: 32032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 8
#   iterations_since_restore: 5
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 64.34444444444445
#     ram_util_percent: 21.9
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07954345181042008
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5937571832842474
#     mean_inference_ms: 2.716771899970587
#     mean_raw_obs_processing_ms: 0.21005481961397246
#   time_since_restore: 29.53032612800598
#   time_this_iter_s: 6.043963670730591
#   time_total_s: 29.53032612800598
#   timers:
#     learn_throughput: 5690.206
#     learn_time_ms: 5.624
#     load_throughput: 30580.48
#     load_time_ms: 1.046
#   timestamp: 1650661172
#   timesteps_since_restore: 160
#   timesteps_this_iter: 32
#   timesteps_total: 5000
#   training_iteration: 5
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:35 (running for 00:00:45.45)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     5</td><td style="text-align: right;">         29.5303</td><td style="text-align: right;">5000</td><td style="text-align: right;"> 1.31579</td><td style="text-align: right;">                   3</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           250.632</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 6000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-38
#   done: false
#   episode_len_mean: 249.56521739130434
#   episode_media: {}
#   episode_reward_max: 4.0
#   episode_reward_mean: 1.3043478260869565
#   episode_reward_min: 0.0
#   episodes_this_iter: 4
#   episodes_total: 23
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 5536
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 1.9546875953674316
#           mean_q: 1.2944191694259644
#           mean_td_error: 0.05289933830499649
#           min_q: 0.8572443723678589
#           model: {}
#         td_error:
#         - -0.017761707305908203
#         - 0.13988769054412842
#         - 0.13444340229034424
#         - 0.08395588397979736
#         - 0.15848898887634277
#         - 0.0334172248840332
#         - 0.07834136486053467
#         - -0.021541476249694824
#         - 0.09539103507995605
#         - 0.1842135190963745
#         - 0.0325237512588501
#         - -0.08417743444442749
#         - 0.15200525522232056
#         - 0.20713448524475098
#         - 0.07658171653747559
#         - 0.10611915588378906
#         - 0.12176191806793213
#         - 0.01997959613800049
#         - 0.025987625122070312
#         - 0.22312593460083008
#         - 0.19289958477020264
#         - 0.03609800338745117
#         - -0.22235441207885742
#         - 0.006585359573364258
#         - -0.02066218852996826
#         - 0.00327146053314209
#         - 0.08697736263275146
#         - 0.07194840908050537
#         - -0.04988205432891846
#         - -0.004136323928833008
#         - 0.0386883020401001
#         - -0.19653254747390747
#         train: null
#     num_agent_steps_sampled: 6000
#     num_agent_steps_trained: 40032
#     num_steps_sampled: 6000
#     num_steps_trained: 40032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 10
#   iterations_since_restore: 6
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 65.10000000000001
#     ram_util_percent: 21.92222222222222
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07948577699422098
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.593044346426212
#     mean_inference_ms: 2.7024230378686127
#     mean_raw_obs_processing_ms: 0.21094793427065053
#   time_since_restore: 35.69660496711731
#   time_this_iter_s: 6.166278839111328
#   time_total_s: 35.69660496711731
#   timers:
#     learn_throughput: 5748.821
#     learn_time_ms: 5.566
#     load_throughput: 34199.956
#     load_time_ms: 0.936
#   timestamp: 1650661178
#   timesteps_since_restore: 192
#   timesteps_this_iter: 32
#   timesteps_total: 6000
#   training_iteration: 6
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:40 (running for 00:00:50.58)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     6</td><td style="text-align: right;">         35.6966</td><td style="text-align: right;">6000</td><td style="text-align: right;"> 1.30435</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           249.565</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 7000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-44
#   done: false
#   episode_len_mean: 253.5185185185185
#   episode_media: {}
#   episode_reward_max: 4.0
#   episode_reward_mean: 1.3333333333333333
#   episode_reward_min: 0.0
#   episodes_this_iter: 4
#   episodes_total: 27
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 6544
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 1.8990358114242554
#           mean_q: 1.246891975402832
#           mean_td_error: -0.04186982661485672
#           min_q: 0.8018941879272461
#           model: {}
#         td_error:
#         - -0.05975532531738281
#         - -0.09624075889587402
#         - -0.01975572109222412
#         - -0.08827388286590576
#         - -0.010434746742248535
#         - -0.15459740161895752
#         - -0.09385550022125244
#         - -0.13436269760131836
#         - -0.15908026695251465
#         - -0.11669135093688965
#         - -0.04651188850402832
#         - -0.0559004545211792
#         - 0.013472199440002441
#         - -0.05819594860076904
#         - -0.12024986743927002
#         - -0.07010161876678467
#         - -0.1774294376373291
#         - -0.07042348384857178
#         - -0.09316682815551758
#         - 1.0161327123641968
#         - -0.15467560291290283
#         - -0.1474372148513794
#         - -0.03714883327484131
#         - -0.022502541542053223
#         - -0.12736815214157104
#         - -0.08827388286590576
#         - -0.04005169868469238
#         - -0.06790614128112793
#         - -0.04734599590301514
#         - -0.0010451078414916992
#         - -0.027390241622924805
#         - 0.016733169555664062
#         train: null
#     num_agent_steps_sampled: 7000
#     num_agent_steps_trained: 48032
#     num_steps_sampled: 7000
#     num_steps_trained: 48032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 12
#   iterations_since_restore: 7
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 64.6
#     ram_util_percent: 22.0
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07942864556117488
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5922236713561941
#     mean_inference_ms: 2.689888552122381
#     mean_raw_obs_processing_ms: 0.21135109355170326
#   time_since_restore: 41.78743529319763
#   time_this_iter_s: 6.090830326080322
#   time_total_s: 41.78743529319763
#   timers:
#     learn_throughput: 5888.189
#     learn_time_ms: 5.435
#     load_throughput: 32373.605
#     load_time_ms: 0.988
#   timestamp: 1650661184
#   timesteps_since_restore: 224
#   timesteps_this_iter: 32
#   timesteps_total: 7000
#   training_iteration: 7
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:45 (running for 00:00:55.77)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     7</td><td style="text-align: right;">         41.7874</td><td style="text-align: right;">7000</td><td style="text-align: right;"> 1.33333</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           253.519</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 20:59:50 (running for 00:01:00.78)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     7</td><td style="text-align: right;">         41.7874</td><td style="text-align: right;">7000</td><td style="text-align: right;"> 1.33333</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">           253.519</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 8000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-51
#   done: false
#   episode_len_mean: 258.0
#   episode_media: {}
#   episode_reward_max: 4.0
#   episode_reward_mean: 1.3225806451612903
#   episode_reward_min: 0.0
#   episodes_this_iter: 4
#   episodes_total: 31
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 7552
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 1.9893913269042969
#           mean_q: 1.2922171354293823
#           mean_td_error: 0.035465341061353683
#           min_q: 0.8997527360916138
#           model: {}
#         td_error:
#         - 0.0692434310913086
#         - 0.0108107328414917
#         - 0.1193394660949707
#         - -0.058123230934143066
#         - 0.023302078247070312
#         - 0.16321688890457153
#         - -0.011044740676879883
#         - 0.006249547004699707
#         - 0.08908522129058838
#         - 0.1354532241821289
#         - 0.018575191497802734
#         - 0.025534510612487793
#         - -0.04359102249145508
#         - 0.0030364990234375
#         - 0.041594624519348145
#         - -0.03297889232635498
#         - -0.007133126258850098
#         - -0.03161978721618652
#         - -0.07383584976196289
#         - 0.06516361236572266
#         - -0.06738996505737305
#         - 0.0724102258682251
#         - 0.01775670051574707
#         - 0.060986995697021484
#         - 0.17072808742523193
#         - 0.14553076028823853
#         - -0.07504665851593018
#         - 0.1489506959915161
#         - -0.013724565505981445
#         - -0.04851937294006348
#         - 0.20406806468963623
#         - 0.006861567497253418
#         train: null
#     num_agent_steps_sampled: 8000
#     num_agent_steps_trained: 56032
#     num_steps_sampled: 8000
#     num_steps_trained: 56032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 14
#   iterations_since_restore: 8
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 65.0
#     ram_util_percent: 22.0
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07938937972146506
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5916814104141608
#     mean_inference_ms: 2.6798733445272225
#     mean_raw_obs_processing_ms: 0.21162108665771318
#   time_since_restore: 48.03399133682251
#   time_this_iter_s: 6.246556043624878
#   time_total_s: 48.03399133682251
#   timers:
#     learn_throughput: 5866.236
#     learn_time_ms: 5.455
#     load_throughput: 25477.445
#     load_time_ms: 1.256
#   timestamp: 1650661191
#   timesteps_since_restore: 256
#   timesteps_this_iter: 32
#   timesteps_total: 8000
#   training_iteration: 8
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 20:59:56 (running for 00:01:06.09)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     8</td><td style="text-align: right;">          48.034</td><td style="text-align: right;">8000</td><td style="text-align: right;"> 1.32258</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">               258</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 9000
#   custom_metrics: {}
#   date: 2022-04-22_20-59-57
#   done: false
#   episode_len_mean: 259.5
#   episode_media: {}
#   episode_reward_max: 4.0
#   episode_reward_mean: 1.3235294117647058
#   episode_reward_min: 0.0
#   episodes_this_iter: 3
#   episodes_total: 34
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 8560
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 2.1149260997772217
#           mean_q: 1.4182679653167725
#           mean_td_error: -0.007881198078393936
#           min_q: 0.9718214273452759
#           model: {}
#         td_error:
#         - -0.06559693813323975
#         - -0.09766197204589844
#         - -0.03989613056182861
#         - 0.04067361354827881
#         - 0.22961318492889404
#         - -0.395175576210022
#         - -0.071036696434021
#         - -0.0246354341506958
#         - 0.018893957138061523
#         - -0.062424302101135254
#         - -0.10689759254455566
#         - 0.09102737903594971
#         - -0.07459986209869385
#         - 0.25975191593170166
#         - -0.06472945213317871
#         - -0.5093884468078613
#         - 0.029971837997436523
#         - -0.11446857452392578
#         - 1.1325292587280273
#         - -0.10674715042114258
#         - 0.17882299423217773
#         - -0.04369556903839111
#         - -0.08217370510101318
#         - 0.021252989768981934
#         - -0.08064389228820801
#         - -0.08352386951446533
#         - -0.02200782299041748
#         - -0.03568708896636963
#         - -0.10322451591491699
#         - 0.162550687789917
#         - -0.12129580974578857
#         - -0.11177575588226318
#         train: null
#     num_agent_steps_sampled: 9000
#     num_agent_steps_trained: 64032
#     num_steps_sampled: 9000
#     num_steps_trained: 64032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 16
#   iterations_since_restore: 9
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 64.98888888888888
#     ram_util_percent: 22.055555555555557
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07937626413767329
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5912130633264807
#     mean_inference_ms: 2.6731548743791795
#     mean_raw_obs_processing_ms: 0.2117437110258915
#   time_since_restore: 54.18748378753662
#   time_this_iter_s: 6.153492450714111
#   time_total_s: 54.18748378753662
#   timers:
#     learn_throughput: 5670.732
#     learn_time_ms: 5.643
#     load_throughput: 33922.491
#     load_time_ms: 0.943
#   timestamp: 1650661197
#   timesteps_since_restore: 288
#   timesteps_this_iter: 32
#   timesteps_total: 9000
#   training_iteration: 9
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 21:00:01 (running for 00:01:11.19)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     9</td><td style="text-align: right;">         54.1875</td><td style="text-align: right;">9000</td><td style="text-align: right;"> 1.32353</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">             259.5</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 21:00:06 (running for 00:01:16.27)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     9</td><td style="text-align: right;">         54.1875</td><td style="text-align: right;">9000</td><td style="text-align: right;"> 1.32353</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">             259.5</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 21:00:11 (running for 00:01:21.28)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     9</td><td style="text-align: right;">         54.1875</td><td style="text-align: right;">9000</td><td style="text-align: right;"> 1.32353</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">             259.5</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 21:00:16 (running for 00:01:26.33)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     9</td><td style="text-align: right;">         54.1875</td><td style="text-align: right;">9000</td><td style="text-align: right;"> 1.32353</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">             259.5</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 21:00:21 (running for 00:01:31.34)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">     9</td><td style="text-align: right;">         54.1875</td><td style="text-align: right;">9000</td><td style="text-align: right;"> 1.32353</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                   0</td><td style="text-align: right;">             259.5</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 21:00:26 (running for 00:01:36.38)<br>Memory usage on this node: 2.8/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# ...
#     num_target_updates: 502
#   iterations_since_restore: 254
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 67.33333333333334
#     ram_util_percent: 23.9
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07840099922761404
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5813441122094286
#     mean_inference_ms: 2.8884734607378446
#     mean_raw_obs_processing_ms: 0.1958525638268663
#   time_since_restore: 2572.7450087070465
#   time_this_iter_s: 6.593421936035156
#   time_total_s: 2572.7450087070465
#   timers:
#     learn_throughput: 6189.085
#     learn_time_ms: 5.17
#     load_throughput: 35191.727
#     load_time_ms: 0.909
#   timestamp: 1650663725
#   timesteps_since_restore: 8128
#   timesteps_this_iter: 32
#   timesteps_total: 254000
#   training_iteration: 254
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 21:42:06 (running for 00:43:16.52)<br>Memory usage on this node: 3.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">   254</td><td style="text-align: right;">         2572.75</td><td style="text-align: right;">254000</td><td style="text-align: right;">     4.8</td><td style="text-align: right;">                  13</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            421.29</td></tr>
# </tbody>
# </table><br><br>
# == Status ==<br>Current time: 2022-04-22 21:42:11 (running for 00:43:21.52)<br>Memory usage on this node: 3.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">   254</td><td style="text-align: right;">         2572.75</td><td style="text-align: right;">254000</td><td style="text-align: right;">     4.8</td><td style="text-align: right;">                  13</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            421.29</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 255000
#   custom_metrics: {}
#   date: 2022-04-22_21-42-12
#   done: false
#   episode_len_mean: 425.05
#   episode_media: {}
#   episode_reward_max: 13.0
#   episode_reward_mean: 4.88
#   episode_reward_min: 0.0
#   episodes_this_iter: 3
#   episodes_total: 670
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 254512
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 2.492934465408325
#           mean_q: 1.6865984201431274
#           mean_td_error: -0.032569557428359985
#           min_q: 1.1395227909088135
#           model: {}
#         td_error:
#         - 0.03143274784088135
#         - 0.1597127914428711
#         - -2.8677141666412354
#         - 0.005728483200073242
#         - 0.03828084468841553
#         - 0.054448723793029785
#         - 0.051455140113830566
#         - 0.020633459091186523
#         - 0.026444435119628906
#         - 0.10033750534057617
#         - -0.268623948097229
#         - 0.11217689514160156
#         - 0.46098995208740234
#         - 0.04025924205780029
#         - 0.02867865562438965
#         - 0.035395145416259766
#         - -0.00397038459777832
#         - 0.10688436031341553
#         - 0.03486514091491699
#         - 0.0327448844909668
#         - 0.029346466064453125
#         - -0.023765921592712402
#         - -0.006953001022338867
#         - 0.02706742286682129
#         - 0.027205944061279297
#         - 0.03688359260559082
#         - 0.04760611057281494
#         - -0.08415722846984863
#         - 0.37216460704803467
#         - 0.036150455474853516
#         - 0.2614966034889221
#         - 0.03456926345825195
#         train: null
#     num_agent_steps_sampled: 255000
#     num_agent_steps_trained: 2032032
#     num_steps_sampled: 255000
#     num_steps_trained: 2032032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 504
#   iterations_since_restore: 255
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 66.10000000000001
#     ram_util_percent: 23.9
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07839486491519632
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5813111416455301
#     mean_inference_ms: 2.88836195447565
#     mean_raw_obs_processing_ms: 0.19582366039613863
#   time_since_restore: 2579.329259157181
#   time_this_iter_s: 6.584250450134277
#   time_total_s: 2579.329259157181
#   timers:
#     learn_throughput: 5698.565
#     learn_time_ms: 5.615
#     load_throughput: 32467.58
#     load_time_ms: 0.986
#   timestamp: 1650663732
#   timesteps_since_restore: 8160
#   timesteps_this_iter: 32
#   timesteps_total: 255000
#   training_iteration: 255
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 21:42:17 (running for 00:43:27.35)<br>Memory usage on this node: 3.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">   255</td><td style="text-align: right;">         2579.33</td><td style="text-align: right;">255000</td><td style="text-align: right;">    4.88</td><td style="text-align: right;">                  13</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            425.05</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 256000
#   custom_metrics: {}
#   date: 2022-04-22_21-42-18
#   done: false
#   episode_len_mean: 426.39
#   episode_media: {}
#   episode_reward_max: 13.0
#   episode_reward_mean: 4.92
#   episode_reward_min: 0.0
#   episodes_this_iter: 1
#   episodes_total: 671
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 255520
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 2.399876356124878
#           mean_q: 1.6494140625
#           mean_td_error: 0.04019375145435333
#           min_q: 0.727883517742157
#           model: {}
#         td_error:
#         - 0.049956679344177246
#         - 0.1435391902923584
#         - 0.04551684856414795
#         - 0.024008631706237793
#         - 0.017469286918640137
#         - -0.002011537551879883
#         - 0.02717411518096924
#         - 0.09974038600921631
#         - 0.06949400901794434
#         - 0.002756834030151367
#         - 0.06181192398071289
#         - 0.002510547637939453
#         - -0.0029380321502685547
#         - -0.029526591300964355
#         - 0.00685429573059082
#         - 0.12444496154785156
#         - 0.006700754165649414
#         - 0.05424928665161133
#         - 0.312448650598526
#         - 0.07509410381317139
#         - -0.07895898818969727
#         - 0.18644630908966064
#         - -0.005701541900634766
#         - -0.006037235260009766
#         - -0.002305746078491211
#         - 0.04395735263824463
#         - 0.12937414646148682
#         - 0.051030516624450684
#         - 0.017213106155395508
#         - -0.12212884426116943
#         - -0.004122734069824219
#         - -0.01186060905456543
#         train: null
#     num_agent_steps_sampled: 256000
#     num_agent_steps_trained: 2040032
#     num_steps_sampled: 256000
#     num_steps_trained: 2040032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 506
#   iterations_since_restore: 256
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 67.07777777777778
#     ram_util_percent: 23.9
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07839292630369091
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5813014628861946
#     mean_inference_ms: 2.8883265648411522
#     mean_raw_obs_processing_ms: 0.19581308415623538
#   time_since_restore: 2585.9180996418
#   time_this_iter_s: 6.588840484619141
#   time_total_s: 2585.9180996418
#   timers:
#     learn_throughput: 6021.703
#     learn_time_ms: 5.314
#     load_throughput: 33469.086
#     load_time_ms: 0.956
#   timestamp: 1650663738
#   timesteps_since_restore: 8192
#   timesteps_this_iter: 32
#   timesteps_total: 256000
#   training_iteration: 256
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 21:42:22 (running for 00:43:32.76)<br>Memory usage on this node: 3.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1.0/2 CPUs, 1.0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>RUNNING </td><td>172.28.0.2:1651</td><td style="text-align: right;">   256</td><td style="text-align: right;">         2585.92</td><td style="text-align: right;">256000</td><td style="text-align: right;">    4.92</td><td style="text-align: right;">                  13</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            426.39</td></tr>
# </tbody>
# </table><br><br>
# Result for DQN_Breakout-ram-v0_02894_00000:
#   agent_timesteps_total: 257000
#   custom_metrics: {}
#   date: 2022-04-22_21-42-25
#   done: true
#   episode_len_mean: 432.88
#   episode_media: {}
#   episode_reward_max: 13.0
#   episode_reward_mean: 5.03
#   episode_reward_min: 0.0
#   episodes_this_iter: 2
#   episodes_total: 673
#   experiment_id: b6c359f203ae460e8406d0db20984161
#   hostname: e4fed5a56747
#   info:
#     last_target_update_ts: 256528
#     learner:
#       default_policy:
#         learner_stats:
#           cur_lr: 0.0005000000237487257
#           max_q: 2.3730719089508057
#           mean_q: 1.5923550128936768
#           mean_td_error: 0.0023896507918834686
#           min_q: 0.9900310635566711
#           model: {}
#         td_error:
#         - 0.010199308395385742
#         - 0.06239354610443115
#         - 0.03838825225830078
#         - 0.047747135162353516
#         - 0.025039076805114746
#         - 0.037882447242736816
#         - 0.09353387355804443
#         - 0.007621645927429199
#         - 0.12205779552459717
#         - 0.0361407995223999
#         - 0.030238628387451172
#         - 0.05410122871398926
#         - 0.059027910232543945
#         - 0.036759376525878906
#         - 0.027504563331604004
#         - 0.02282726764678955
#         - 0.16744160652160645
#         - 0.036701083183288574
#         - -0.18755316734313965
#         - 0.09891217947006226
#         - 0.05912935733795166
#         - 0.05631697177886963
#         - 0.02248513698577881
#         - -0.2094273567199707
#         - -0.004804730415344238
#         - 0.054601430892944336
#         - -0.5206356048583984
#         - 0.049794673919677734
#         - -0.35772615671157837
#         - -0.0038254261016845703
#         - 0.040006160736083984
#         - 0.06358981132507324
#         train: null
#     num_agent_steps_sampled: 257000
#     num_agent_steps_trained: 2048032
#     num_steps_sampled: 257000
#     num_steps_trained: 2048032
#     num_steps_trained_this_iter: 32
#     num_target_updates: 508
#   iterations_since_restore: 257
#   node_ip: 172.28.0.2
#   num_healthy_workers: 0
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 67.49000000000001
#     ram_util_percent: 23.9
#   pid: 1651
#   policy_reward_max: {}
#   policy_reward_mean: {}
#   policy_reward_min: {}
#   sampler_perf:
#     mean_action_processing_ms: 0.07838907808444612
#     mean_env_render_ms: 0.0
#     mean_env_wait_ms: 0.5812835292831909
#     mean_inference_ms: 2.8882601254561973
#     mean_raw_obs_processing_ms: 0.195791563496892
#   time_since_restore: 2592.621626138687
#   time_this_iter_s: 6.703526496887207
#   time_total_s: 2592.621626138687
#   timers:
#     learn_throughput: 5867.185
#     learn_time_ms: 5.454
#     load_throughput: 29500.347
#     load_time_ms: 1.085
#   timestamp: 1650663745
#   timesteps_since_restore: 8224
#   timesteps_this_iter: 32
#   timesteps_total: 257000
#   training_iteration: 257
#   trial_id: 02894_00000
# == Status ==<br>Current time: 2022-04-22 21:42:25 (running for 00:43:35.64)<br>Memory usage on this node: 3.0/12.7 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/6.87 GiB heap, 0.0/3.44 GiB objects (0.0/1.0 accelerator_type:P100)<br>Result logdir: /content/drive/MyDrive/INM707/breakout_v1/DQN<br>Number of trials: 1/1 (1 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name                     </th><th>status    </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">    ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Breakout-ram-v0_02894_00000</td><td>TERMINATED</td><td>172.28.0.2:1651</td><td style="text-align: right;">   257</td><td style="text-align: right;">         2592.62</td><td style="text-align: right;">257000</td><td style="text-align: right;">    5.03</td><td style="text-align: right;">                  13</td><td style="text-align: right;">                   0</td><td style="text-align: right;">            432.88</td></tr>
# </tbody>
# </table><br><br>
# 2022-04-22 21:42:26,315	INFO tune.py:639 -- Total run time: 2616.24 seconds (2615.51 seconds for the tuning loop).

# %%
df = analysis.dataframe(metric="episode_reward_mean", mode="max")

# %%
df.head()
# Out:
#    episode_reward_max  episode_reward_min  episode_reward_mean  \
# 0                13.0                 0.0                 5.03
#
#    episode_len_mean  episodes_this_iter  num_healthy_workers  timesteps_total  \
# 0            432.88                   2                    0           257000
#
#    timesteps_this_iter  agent_timesteps_total  done  ...  \
# 0                   32                 257000  True  ...
#
#    config/synchronize_filters  config/target_network_update_freq  \
# 0                        True                                500
#
#                               config/tf_session_args  \
# 0  {'allow_soft_placement': True, 'device_count':...
#
#   config/timesteps_per_iteration config/train_batch_size  \
# 0                           1000                      32
#
#    config/training_intensity  config/v_max  config/v_min  \
# 0                       None          10.0         -10.0
#
#    config/worker_side_prioritization  \
# 0                              False
#
#                                               logdir
# 0  /content/drive/MyDrive/INM707/breakout_v1/DQN/...
#
# [1 rows x 168 columns]

# %% [markdown]
# #Restore Agent

# %%
checkpoint_file = '/content/drive/MyDrive/INM707/breakout_v1/DQN/DQN_Breakout-ram-v0_02894_00000_0_2022-04-22_20-58-50/checkpoint_000250/checkpoint-250'
agent = dqn.DQNTrainer(config=config)
agent.restore(checkpoint_file)
# Out:
# 2022-04-24 12:09:16,164	WARNING deprecation.py:46 -- DeprecationWarning: `simple_optimizer` has been deprecated. This will raise an error in the future!
# Install gputil for GPU system monitoring.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/ray/rllib/utils/exploration/epsilon_greedy.py:218: Variable.load (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Prefer Variable.assign which has equivalent behavior in 2.X.
# 2022-04-24 12:09:25,521	INFO trainable.py:496 -- Restored on 172.28.0.2 from checkpoint: /content/drive/MyDrive/INM707/breakout_v1/DQN/DQN_Breakout-ram-v0_02894_00000_0_2022-04-22_20-58-50/checkpoint_000250/checkpoint-250
# 2022-04-24 12:09:25,523	INFO trainable.py:503 -- Current state after restoring: {'_iteration': 250, '_timesteps_total': 8000, '_time_total': 2546.3796491622925, '_episodes_total': 659}

# %%
import gym
done = False

env = wrap_env(gym.make('Breakout-ram-v0'))
state = env.reset()
total_reward = 0 

while not done:
    action = agent.compute_single_action(state)

    state, reward, done, _ = env.step(action) 
    total_reward += reward

    #env.render()


env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
print(total_reward)
# Out:
# 5.0
